# %%
import requests
import json
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Important: Store somewhere
api_key = 'd2187477-4cc3-49f3-8878-2d42c6ee3385'

# %%
##Function to fetch articles

def fetch_articles(api_key, section, from_date, to_date, page=1):
    base_url = "https://content.guardianapis.com/search"
    params = {
        'api-key': api_key,
        'section': section,
        'from-date': from_date,
        'to-date': to_date,
        'page': page,
        'show-fields': 'body,headline,lastModified',
        'show-tags': 'contributor'
    }

    
    response = requests.get(base_url, params=params)
    data = response.json()    
    return data['response']['results']

def create_dataframe(api_key, section, from_date, to_date, max_pages=100):
    all_articles = []

    for page in range(1, max_pages + 1):
        articles = fetch_articles(api_key, section, from_date, to_date, page)
        for article in articles:
            author = next((tag['webTitle'] for tag in article['tags'] if tag['type'] == 'contributor'), 'Unknown')
            all_articles.append({
                'Author': author,
                'Title': article['fields']['headline'],
                'Section': article['sectionName'],
                'Content': article['fields']['body'],
                'Date': article['fields']['lastModified']
            })

    return pd.DataFrame(all_articles)
# Out:
#              Author                                              Title  \
# 0  Allegra Stratton  Conservative grassroots fear new rule will bri...
# 1  Allegra Stratton        John Bercow facing Tory backbench challenge
# 2     Michael White  Love Tony Blair or loathe him, only one choice...
# 3       Alan Travis  Police policy on deletion of DNA records is sh...
# 4     Michael White  Michael White's politicians of the decade: Dav...
#
#     Section                                            Content  \
# 0  Politics  <p>Tory grassroots activists are braced for a ...
# 1  Politics  <p>Tory MPs are pushing for the removal of the...
# 2  Politics  <p>Politician of the decade? Even to ask the q...
# 3  Politics  <p>Police policy on deleting the DNA records o...
# 4  Politics  <p><strong>At the start of the decade </strong...
#
#                    Date
# 0  2017-11-27T09:00:58Z
# 1  2017-11-27T09:00:59Z
# 2  2017-11-27T09:01:21Z
# 3  2017-11-27T09:01:27Z
# 4  2017-06-09T19:47:19Z

# %%
section = 'politics'  
from_date = '1999-01-01'
to_date = '2009-12-31'

df = create_dataframe(api_key, section, from_date, to_date)
print(df.head())
# Out:
# '<p>Tory grassroots activists are braced for a battle of wills with party headquarters as new rules take effect tomorrow giving the leadership firmer control over the selection of new candidates.</p> <p>In a rule change that will take effect at midnight, any MP retiring from parliament at the election will leave local party members to choose from a Tory central office shortlist of just three candidates.</p> <p>The relationship between the party and its grassroots is particularly bruised after the attempted deselection of Liz Truss in Norfolk when it emerged she had been involved in an extramarital affair, even though she said this had already been made public.</p> <p>Truss won the support of David Cameron, but the local party were unhappy and the attempt to shore her up was perceived as the centre of the party being heavy-handed with smaller associations. She was eventually chosen as prospective candidate for South West Norfolk after a motion to deselect her was defeated.</p> <p>The rule change has been dreaded for months by local activists, who fear it will be used to make selection easier for the appointment of pliable candidates.</p> <p>The editor of the influential Tory blog Conservative Home, Tim Montgomerie, went so far as to say Tory MPs had been persuaded to delay the timing of their retirement until the new period in order for the leadership to more easily manage the selections.</p> <p>He said: "The suspicion is that any MPs who retire now have delayed their announcement at CCHQ\'s request and are likely to be rewarded with peerages."</p> <p>Cameron will also be forced to reveal his zeal for increasing the number of women entering parliament after he said in October last year that he would use the rule change to push through all-women shortlists.</p> <p>Montgomerie said: "CCHQ must not use its new powers to impose candidates that will be slavishly loyal to the leadership. Local associations will also be very unhappy if all-women shortlists are imposed and the women on those lists have no connection with the local area."</p> <p>There have already been 30 Tory MPs who have announced they are leaving parliament and who have had replacement Conservative candidates selected in their place.</p> <p>The former agriculture minister John Gummer announced he is to stand down to form a new international group fighting climate change and he joins three other MPs whose replacement selection process has not yet begun.</p>'

# %%
len(np.unique(df['Section']))
#len(df[df['Author']!= "Unknown"])
# Out:
# 1

# %%
def clean_html_content(html_content):
    # Remove HTML tags
    text = BeautifulSoup(html_content, "html.parser").get_text()

    # Normalize whitespaces
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove backslashes
    text = text.replace('\\', '')
    
    return text

# Applying the cleaning function to the 'Content' column
df['Cleaned_Content'] = df['Content'].apply(clean_html_content)

# Calculate the length of the cleaned content
df['Text_Length'] = df['Cleaned_Content'].apply(len)

# %%
# Using seaborn to plot the distribution
sns.histplot(df['Text_Length'])  

plt.title('Distribution of Article Lengths')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
df.sort_values('Text_Length', ascending=False).head(50)
# Out:
#                 Author                                              Title  \
# 87    Guardian readers             MPs' expenses – what you've discovered
# 146  Hélène Mulholland           MPs' expenses: what we've learned so far
# 178     Andrew Sparrow                           Pre-budget report – live
# 424     Andrew Sparrow                              Queen's speech – live
# 782       Adam Gabbatt                 BNP on Question Time - the buildup
# 614     Andrew Sparrow                       MPs' expenses reforms – live
# 225     Andrew Sparrow                                Iraq inquiry – live
# 310     Andrew Sparrow       Christopher Meyer at Iraq war inquiry – live
# 88      Andrew Sparrow                                Iraq inquiry – live
# 301     Andrew Sparrow                                Iraq inquiry – live
# 776     Andrew Sparrow                               Question Time - live
# 163     Andrew Sparrow                               MPs' expenses – live
# 463        Will Hutton    The great debate: Will Hutton vs George Osborne
# 497          Paul Owen               Glasgow North East byelection – live
# 382     Andrew Sparrow  David Cameron answers questions on Mumsnet - live
# 915  Carole Cadwalladr                       Things can only get bluer...
# 834     Andrew Sparrow  Gordon Brown, David Cameron and Nick Clegg qui...
# 969          Toby Helm  Is  Michal Kaminski fit to lead  the Tories in...
# 805     Andrew Sparrow                   MPs debate gagging of parliament
# 142       Robert Booth  MPs' expenses - how politicians clean up: Stra...
# 866    Stuart Jeffries      Question Time: Does the panel accept racists?
# 727  Hélène Mulholland              David Cameron press conference – live
# 116        Deborah Orr       Theresa May: David Cameron's lady in waiting
# 537     Andrew Sparrow               Gordon Brown press conference – live
# 873    Deborah Summers  MPs' expenses: Who is in the clear, and who ow...
# 430          Paul Owen              The Queen's speech – from the archive
# 124          Toby Helm  Pre-budget report: Labour and Tories compete i...
# 978       Robert Booth             Who is behind the Taxpayers' Alliance?
# 359          Toby Helm  New polls show Britain could face hung parliament
# 203          Toby Helm  Resurgent Brown ready to declare class war on ...
