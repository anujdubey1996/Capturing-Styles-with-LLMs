# %%
import numpy as np
import pandas as pd
import os
from openai import OpenAI

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key= "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",
)
model = "text-embedding-3-small"

# %%
def generate_embeddings_with_small(text, model):
    text = text.replace("\n", " ")
    return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
news_articles = pd.read_csv("../Datasets/TGC/combined_data.csv")

# %%
news_articles = news_articles[['Author', 'Title', 'Section', 'Date', 'Cleaned_Content', 'Text_Length']]

# %%
news_articles['Embedding'] = news_articles['Cleaned_Content'].apply(lambda text: generate_embeddings_with_small(text, model))
# Out:
# /var/folders/vt/0p3h8n2s5r16s2nj4dkldlvm0000gq/T/ipykernel_16902/2780782893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_articles['Embedding'] = news_articles['Cleaned_Content'].apply(lambda text: generate_embeddings_with_small(text, model))

# %%
news_articles
# Out:
#                        Author  \
# 0     Guardian community team
# 1           Alexandra Topping
# 2                Harry Taylor
# 3                 Rajeev Syal
# 4             Heather Stewart
# ...                       ...
# 4764                Ben Quinn
# 4765           Jamie Grierson
# 4766           Sandra Laville
# 4767              Vikram Dodd
# 4768              Vikram Dodd
#
#                                                   Title   Section  \
# 0     UK residents: how will you be impacted by Brexit?  Politics
# 1     Tampon tax: government axes VAT on sanitary pr...  Politics
# 2     Stanley Johnson confirms application for Frenc...  Politics
# 3     Boris Johnson's post-Brexit trade deal passes ...  Politics
# 4     Three Labour frontbenchers quit after defying ...  Politics
# ...                                                 ...       ...
# 4764  London fire tests emergency response amid coro...   UK news
# ...

# %%
# Save to Parquet
news_articles.to_parquet('embeddings.parquet')
